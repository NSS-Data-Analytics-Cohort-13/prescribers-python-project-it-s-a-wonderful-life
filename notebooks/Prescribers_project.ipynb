# %%
from sqlalchemy import create_engine, text

# %%
import pandas as pd

# %%
database_name = 'Prescribers'    # Fill this in with your lahman database name

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/Prescribers)

# %%
cbsa1 = '''
SELECT *
FROM cbsa
'''

with engine.connect() as connection:
    cbsa = pd.read_sql(text(cbsa1), con = connection)

cbsa.head()
# Out:
#   fipscounty   cbsa                          cbsaname
# 0      01001  33860                    Montgomery, AL
# 1      01003  19300         Daphne-Fairhope-Foley, AL
# 2      01007  13820             Birmingham-Hoover, AL
# 3      01009  13820             Birmingham-Hoover, AL
# 4      01015  11500  Anniston-Oxford-Jacksonville, AL

# %%
prescriber1 = '''
SELECT *
FROM prescriber
'''

with engine.connect() as connection:
    prescriber = pd.read_sql(text(prescriber1), con = connection)

prescriber.head()
# Out:
#             npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1.003000e+09                    BLAKEMORE                     ROSIE
# 1  1.003012e+09                      CUDZILO                     COREY
# 2  1.003013e+09                  GRABENSTEIN                   WILLIAM
# 3  1.003014e+09                         OTTO                    ROBERT
# 4  1.003018e+09                         TODD                    JOSHUA
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0                 K               FNP                     F                 I
# 1              None              M.D.                     M                 I
# 2                 P              M.D.                     M                 I
# 3                 J              M.D.                     M                 I
# 4                 W              M.D.                     M                 I
#
# ...

# %%
zip_fips1 = '''
SELECT *
FROM zip_fips
'''

with engine.connect() as connection:
    zip_fips = pd.read_sql(text(zip_fips1), con = connection)

zip_fips.head()
# Out:
#      zip fipscounty  res_ratio  bus_ratio  oth_ratio  tot_ratio
# 0  00501      36103   0.000000    1.00000   0.000000   1.000000
# 1  00601      72113   0.160724    0.20098   0.128834   0.162500
# 2  00601      72001   0.839276    0.79902   0.871166   0.837500
# 3  00602      72003   1.000000    0.99880   1.000000   0.999919
# 4  00602      72005   0.000000    0.00120   0.000000   0.000081

# %%
drug1 = '''
SELECT *
FROM drug
'''

with engine.connect() as connection:
    drug = pd.read_sql(text(drug1), con = connection)

drug.head()
# Out:
#                         drug_name                    generic_name  \
# 0        1ST TIER UNIFINE PENTIPS            PEN NEEDLE, DIABETIC
# 1   1ST TIER UNIFINE PENTIPS PLUS            PEN NEEDLE, DIABETIC
# 2                        ABACAVIR                ABACAVIR SULFATE
# 3             ABACAVIR-LAMIVUDINE     ABACAVIR SULFATE/LAMIVUDINE
# 4  ABACAVIR-LAMIVUDINE-ZIDOVUDINE  ABACAVIR/LAMIVUDINE/ZIDOVUDINE
#
#   opioid_drug_flag long_acting_opioid_drug_flag antibiotic_drug_flag  \
# 0                N                            N                    N
# 1                N                            N                    N
# 2                N                            N                    N
# 3                N                            N                    N
# 4                N                            N                    N
#
#   antipsychotic_drug_flag
# 0                       N
# 1                       N
# 2                       N
# 3                       N
# ...

# %%
population1 = '''
SELECT *
FROM population
'''

with engine.connect() as connection:
    population = pd.read_sql(text(population1), con = connection)

population.head()
# Out:
#   fipscounty  population
# 0      47017     28137.0
# 1      47023     17097.0
# 2      47039     11681.0
# 3      47037    678322.0
# 4      47087     11573.0

# %%
fips_county1 = '''
SELECT *
FROM fips_county
'''

with engine.connect() as connection:
    fips_county = pd.read_sql(text(fips_county1), con = connection)

fips_county.head()
# Out:
#     county state fipscounty fipsstate
# 0  AUTAUGA    AL      01001        01
# 1  BALDWIN    AL      01003        01
# 2  BARBOUR    AL      01005        01
# 3     BIBB    AL      01007        01
# 4   BLOUNT    AL      01009        01

# %%
overdose_deaths1 = '''
SELECT *
FROM overdose_deaths
'''

with engine.connect() as connection:
    overdose_deaths = pd.read_sql(text(overdose_deaths1), con = connection)

overdose_deaths.head()
# Out:
#    overdose_deaths  year  fipscounty
# 0              135  2015       47157
# 1              150  2016       47157
# 2              159  2017       47157
# 3              123  2018       47157
# 4              122  2015       47093

# %%
prescription1 = '''
SELECT *
FROM prescription
'''

with engine.connect() as connection:
    prescription = pd.read_sql(text(prescription1), con = connection)

prescription.head()
# Out:
#             npi       drug_name  bene_count  total_claim_count  \
# 0  1.427076e+09  RALOXIFENE HCL         NaN               18.0
# 1  1.003858e+09     GLIMEPIRIDE         NaN               12.0
# 2  1.184627e+09  TAMSULOSIN HCL         NaN               14.0
# 3  1.306111e+09         SPIRIVA         NaN               13.0
# 4  1.285658e+09         SPIRIVA         NaN               13.0
#
#    total_30_day_fill_count  total_day_supply  total_drug_cost  \
# 0                     28.0             840.0          1009.66
# 1                     16.0             480.0           270.86
# 2                     24.0             698.0           353.62
# 3                     13.0             390.0          4783.28
# 4                     13.0             390.0          4855.95
#
#    bene_count_ge65 bene_count_ge65_suppress_flag  total_claim_count_ge65  \
# 0              NaN                             *                    18.0
# ...

# %% [markdown]
# ## # Tennessee's Opioid Crisis
#
# Opioids are a class of drugs including prescription pain relievers such as oxycodone and hydrocodone, the synthetic opioid fentanyl, and the illegal drug heroin. These drugs produce euphoria in addition to pain relief, which can lead to dependence, addiction, overdose, and death.
#
# In the late 1990s, opioids began to be prescribed at high rates, which led to widespread misuse and ultimately created a serious national health crisis. In 2019, more than 130 people per day died from opioid-related drug overdoses in the United States. Tennessee has been one of the hardest-hit states in the opioid epidemic, with more than 1300 overdose deaths in 2018.

# %% [markdown]
# ## Question #1: * Which Tennessee counties had a disproportionately high number of opioid prescriptions?

# %%
opioid_drugs = drug[drug['opioid_drug_flag']==1]['drug_name']

# %%
opioid_prescription = prescription[prescription['drug_name'].isin(opioid_drugs)]

# %%
opioid_summary = opioid_prescription.groupby(npi)['total_claim_count'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 opioid_summary = opioid_prescription.groupby(npi)['total_claim_count'].sum().reset_index()
#
# NameError: name 'npi' is not defined

# %%
opioid_with_prescribers = opioid_prescription.merge(prescriber, on='npi')

# %%
opioid_with_prescribers
# Out:
# Empty DataFrame
# Columns: [npi, drug_name, bene_count, total_claim_count, total_30_day_fill_count, total_day_supply, total_drug_cost, bene_count_ge65, bene_count_ge65_suppress_flag, total_claim_count_ge65, ge65_suppress_flag, total_30_day_fill_count_ge65, total_day_supply_ge65, total_drug_cost_ge65, nppes_provider_last_org_name, nppes_provider_first_name, nppes_provider_mi, nppes_credentials, nppes_provider_gender, nppes_entity_code, nppes_provider_street1, nppes_provider_street2, nppes_provider_city, nppes_provider_zip5, nppes_provider_zip4, nppes_provider_state, nppes_provider_country, specialty_description, description_flag, medicare_prvdr_enroll_status]
# Index: []
#
# [0 rows x 30 columns]

# %%
tennessee_counties = fips_county[fips_county['state']=='TN']

# %%
opioid_with_prescriber = opioid_prescription.merge(prescriber, on='npi', how='left')

# %%
opioid_with_prescriber
# Out:
# Empty DataFrame
# Columns: [npi, drug_name, bene_count, total_claim_count, total_30_day_fill_count, total_day_supply, total_drug_cost, bene_count_ge65, bene_count_ge65_suppress_flag, total_claim_count_ge65, ge65_suppress_flag, total_30_day_fill_count_ge65, total_day_supply_ge65, total_drug_cost_ge65, nppes_provider_last_org_name, nppes_provider_first_name, nppes_provider_mi, nppes_credentials, nppes_provider_gender, nppes_entity_code, nppes_provider_street1, nppes_provider_street2, nppes_provider_city, nppes_provider_zip5, nppes_provider_zip4, nppes_provider_state, nppes_provider_country, specialty_description, description_flag, medicare_prvdr_enroll_status]
# Index: []
#
# [0 rows x 30 columns]

# %%
print(opioid_prescription.columns)
# Out:
# Index(['npi', 'drug_name', 'bene_count', 'total_claim_count',
#        'total_30_day_fill_count', 'total_day_supply', 'total_drug_cost',
#        'bene_count_ge65', 'bene_count_ge65_suppress_flag',
#        'total_claim_count_ge65', 'ge65_suppress_flag',
#        'total_30_day_fill_count_ge65', 'total_day_supply_ge65',
#        'total_drug_cost_ge65'],
#       dtype='object')

# %%
print(tennessee_counties.columns)
# Out:
# Index(['county', 'state', 'fipscounty', 'fipsstate'], dtype='object')

# %%
pd.concat([drug, fips_county], axis=1)
# Out:
#                            drug_name                    generic_name  \
# 0           1ST TIER UNIFINE PENTIPS            PEN NEEDLE, DIABETIC
# 1      1ST TIER UNIFINE PENTIPS PLUS            PEN NEEDLE, DIABETIC
# 2                           ABACAVIR                ABACAVIR SULFATE
# 3                ABACAVIR-LAMIVUDINE     ABACAVIR SULFATE/LAMIVUDINE
# 4     ABACAVIR-LAMIVUDINE-ZIDOVUDINE  ABACAVIR/LAMIVUDINE/ZIDOVUDINE
# ...                              ...                             ...
# 3420                         ZYPREXA                      OLANZAPINE
# 3421                ZYPREXA RELPREVV              OLANZAPINE PAMOATE
# 3422                   ZYPREXA ZYDIS                      OLANZAPINE
# 3423                          ZYTIGA             ABIRATERONE ACETATE
# 3424                           ZYVOX                       LINEZOLID
#
#      opioid_drug_flag long_acting_opioid_drug_flag antibiotic_drug_flag  \
# ...

# %%
drug_opioid = pd.merge(drug, prescription, on=['drug_name'], how='outer')

# %%
drug_opioid_location = pd.concat([drug_opioid, fips_county], axis=1)

# %%
drug_opioid_location
# Out:
#                             drug_name          generic_name opioid_drug_flag  \
# 0            1ST TIER UNIFINE PENTIPS  PEN NEEDLE, DIABETIC                N
# 1       1ST TIER UNIFINE PENTIPS PLUS  PEN NEEDLE, DIABETIC                N
# 2                            ABACAVIR      ABACAVIR SULFATE                N
# 3                            ABACAVIR      ABACAVIR SULFATE                N
# 4                            ABACAVIR      ABACAVIR SULFATE                N
# ...                               ...                   ...              ...
# 706500                         ZYTIGA   ABIRATERONE ACETATE                N
# 706501                         ZYTIGA   ABIRATERONE ACETATE                N
# 706502                         ZYTIGA   ABIRATERONE ACETATE                N
# 706503                         ZYTIGA   ABIRATERONE ACETATE                N
# 706504                          ZYVOX             LINEZOLID                N
#
# ...

# %%
drug_opioid_tn = drug_opioid_location[drug_opioid_location['state']=='TN']

# %%
drug_combined_tn = drug_opioid_tn.groupby(['opioid_drug_flag', 'total_day_supply_ge65', 'state']).size().reset_index(name='count')

# %%
drug_opioid_tn.reset_index().sort_values('total_day_supply_ge65')
# Out:
#     index  drug_name generic_name opioid_drug_flag  \
# 34   2504  ACYCLOVIR    ACYCLOVIR                N
# 83   2553  ACYCLOVIR    ACYCLOVIR                N
# 51   2521  ACYCLOVIR    ACYCLOVIR                N
# 82   2552  ACYCLOVIR    ACYCLOVIR                N
# 37   2507  ACYCLOVIR    ACYCLOVIR                N
# ..    ...        ...          ...              ...
# 87   2557  ACYCLOVIR    ACYCLOVIR                N
# 88   2558  ACYCLOVIR    ACYCLOVIR                N
# 90   2560  ACYCLOVIR    ACYCLOVIR                N
# 91   2561  ACYCLOVIR    ACYCLOVIR                N
# 92   2562  ACYCLOVIR    ACYCLOVIR                N
#
#    long_acting_opioid_drug_flag antibiotic_drug_flag antipsychotic_drug_flag  \
# 34                            N                    N                       N
# 83                            N                    N                       N
# 51                            N                    N                       N
# ...

# %%
drug_y = drug_combined[drug_combined['opioid_drug_flag']=='Y']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 drug_y = drug_combined[drug_combined['opioid_drug_flag']=='Y']
#
# NameError: name 'drug_combined' is not defined

# %%
drug_y

# %%
tn_counties = drug

# %%
drug_pre=pd.merge(drug, prescription, on=['drug_name'], how='inner')
drug_pre

# %%
pre_pre=pd.merge(drug_pre, prescriber, on=['npi'], how='inner')
pre_pre

# %%
opioid = drug[drug['opioid_drug_flag']=='Y']

# %%
opioid

# %%
drug_opioid = pd.merge(drug, prescription, on=['drug_name'], how='outer')

# %%
dict(drug_opioid)

# %%
combined = pd.concat([pre_pre, zip_fips], axis=1)

# %%
combined

# %% [markdown]
# ## Question #1: * Which Tennessee counties had a disproportionately high number of opioid prescriptions?

# %% [markdown]
# def find_outliers_iqr(data, column,):
#
#     q1 = data[column].quantile(0.25)
#     q3 = data[column].quantile(0.75)
#     iqr = q3 - q1
#     lower_bound = q1 - 1.5 * iqr
#     upper_bound = q3 + 1.5 * iqr
#
#     outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
#     return outliers

# %% [markdown]
# find_outliers_iqr(drug_fips_pre, )

# %% [markdown]
# drug_fips_pre = pd.concat([drug, fips_county, prescription], axis=1)

# %% [markdown]
# drug_fips_pre

# %% [markdown]
# tennessee_data = (drug_fips_pre[drug_fips_pre['state']=='TN'] & drug_fips_pre['opioid_drug_flag']=='Y')

# %% [markdown]
# tennessee_data

# %% [markdown]
# opioid_data = tennessee_data[tennessee_data['opioid_drug_flag']=='Y']

# %% [markdown]
# opioid_data

# %% [markdown]
# # Question #1: * Which Tennessee counties had a disproportionately high number of opioid prescriptions?

# %%
combined_tables = pd.concat([drug, prescription, population, fips_county], axis=1)

# %%
dict(combined_tables)

# %%
combined_tn = combined_tables[combined_tables['state']=='TN']

# %%
dict(combined_tn)

# %% [markdown]
# ## Question #2: Who are the top opioid prescibers for the state of Tennessee?

# %% [markdown]
# ## Question #3:  What did the trend in overdose deaths due to opioids look like in Tennessee from 2015 to 2018?

# %% [markdown]
# ## Question #4: Is there an association between rates of opioid prescriptions and overdose deaths by county?

# %% [markdown]
# ## Question #5: Is there any association between a particular type of opioid and number of overdose deaths?
