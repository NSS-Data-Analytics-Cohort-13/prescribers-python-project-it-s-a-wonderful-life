# %%
from sqlalchemy import create_engine, text

# %%
database_name = 'prescribers'    # Fill this in with your prescribers database name

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
import pandas as pd

# %%
prescrib = '''
SELECT * FROM prescriber;
'''
with engine.connect() as connection:
   prescriber = pd.read_sql(text(prescrib), con = connection)

prescriber.head()
# Out:
#             npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1.003000e+09                    BLAKEMORE                     ROSIE
# 1  1.003012e+09                      CUDZILO                     COREY
# 2  1.003013e+09                  GRABENSTEIN                   WILLIAM
# 3  1.003014e+09                         OTTO                    ROBERT
# 4  1.003018e+09                         TODD                    JOSHUA
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0                 K               FNP                     F                 I
# 1              None              M.D.                     M                 I
# 2                 P              M.D.                     M                 I
# 3                 J              M.D.                     M                 I
# 4                 W              M.D.                     M                 I
#
#             nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# 0       TENNESSEE PRISON FOR WOMEN     3881 STEWARTS LANE           NASHVILLE
# 1              2240 SUTHERLAND AVE              SUITE 103           KNOXVILLE
# 2                 1822 MEMORIAL DR                   None         CLARKSVILLE
# 3  2400 PATTERSON STREET SUITE 100                   None           NASHVILLE
# 4                1819 W CLINCH AVE              SUITE 108           KNOXVILLE
#
#   nppes_provider_zip5 nppes_provider_zip4 nppes_provider_state  \
# 0               37243                0001                   TN
# 1               37919                2333                   TN
# 2               37043                4605                   TN
# 3               37203                2786                   TN
# 4               37916                2435                   TN
#
#   nppes_provider_country specialty_description description_flag  \
# 0                     US    Nurse Practitioner                S
# 1                     US     Pulmonary Disease                S
# 2                     US       Family Practice                S
# 3                     US    Orthopedic Surgery                S
# 4                     US            Cardiology                S
#
#   medicare_prvdr_enroll_status
# 0                            N
# 1                            E
# 2                            E
# 3                            E
# 4                            E

# %%
cbsa1 = '''
SELECT * FROM prescriber;
'''
with engine.connect() as connection:
    cbsa = pd.read_sql(text(cbsa1), con = connection)

cbsa.head()
# Out:
#             npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1.003000e+09                    BLAKEMORE                     ROSIE
# 1  1.003012e+09                      CUDZILO                     COREY
# 2  1.003013e+09                  GRABENSTEIN                   WILLIAM
# 3  1.003014e+09                         OTTO                    ROBERT
# 4  1.003018e+09                         TODD                    JOSHUA
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0                 K               FNP                     F                 I
# 1              None              M.D.                     M                 I
# 2                 P              M.D.                     M                 I
# 3                 J              M.D.                     M                 I
# 4                 W              M.D.                     M                 I
#
#             nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# 0       TENNESSEE PRISON FOR WOMEN     3881 STEWARTS LANE           NASHVILLE
# 1              2240 SUTHERLAND AVE              SUITE 103           KNOXVILLE
# 2                 1822 MEMORIAL DR                   None         CLARKSVILLE
# 3  2400 PATTERSON STREET SUITE 100                   None           NASHVILLE
# 4                1819 W CLINCH AVE              SUITE 108           KNOXVILLE
#
#   nppes_provider_zip5 nppes_provider_zip4 nppes_provider_state  \
# 0               37243                0001                   TN
# 1               37919                2333                   TN
# 2               37043                4605                   TN
# 3               37203                2786                   TN
# 4               37916                2435                   TN
#
#   nppes_provider_country specialty_description description_flag  \
# 0                     US    Nurse Practitioner                S
# 1                     US     Pulmonary Disease                S
# 2                     US       Family Practice                S
# 3                     US    Orthopedic Surgery                S
# 4                     US            Cardiology                S
#
#   medicare_prvdr_enroll_status
# 0                            N
# 1                            E
# 2                            E
# 3                            E
# 4                            E

# %%
drug1 = '''
SELECT * FROM prescriber;
'''
with engine.connect() as connection:
    drug = pd.read_sql(text(drug1), con = connection)

drug.head()
# Out:
#             npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1.003000e+09                    BLAKEMORE                     ROSIE
# 1  1.003012e+09                      CUDZILO                     COREY
# 2  1.003013e+09                  GRABENSTEIN                   WILLIAM
# 3  1.003014e+09                         OTTO                    ROBERT
# 4  1.003018e+09                         TODD                    JOSHUA
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0                 K               FNP                     F                 I
# 1              None              M.D.                     M                 I
# 2                 P              M.D.                     M                 I
# 3                 J              M.D.                     M                 I
# 4                 W              M.D.                     M                 I
#
#             nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# 0       TENNESSEE PRISON FOR WOMEN     3881 STEWARTS LANE           NASHVILLE
# 1              2240 SUTHERLAND AVE              SUITE 103           KNOXVILLE
# 2                 1822 MEMORIAL DR                   None         CLARKSVILLE
# 3  2400 PATTERSON STREET SUITE 100                   None           NASHVILLE
# 4                1819 W CLINCH AVE              SUITE 108           KNOXVILLE
#
#   nppes_provider_zip5 nppes_provider_zip4 nppes_provider_state  \
# 0               37243                0001                   TN
# 1               37919                2333                   TN
# 2               37043                4605                   TN
# 3               37203                2786                   TN
# 4               37916                2435                   TN
#
#   nppes_provider_country specialty_description description_flag  \
# 0                     US    Nurse Practitioner                S
# 1                     US     Pulmonary Disease                S
# 2                     US       Family Practice                S
# 3                     US    Orthopedic Surgery                S
# 4                     US            Cardiology                S
#
#   medicare_prvdr_enroll_status
# 0                            N
# 1                            E
# 2                            E
# 3                            E
# 4                            E

# %%
fips_county1 = '''
SELECT * FROM prescriber;
'''
with engine.connect() as connection:
    fips_county = pd.read_sql(text(fips_county1), con = connection)

fips_county.head()
# Out:
#             npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1.003000e+09                    BLAKEMORE                     ROSIE
# 1  1.003012e+09                      CUDZILO                     COREY
# 2  1.003013e+09                  GRABENSTEIN                   WILLIAM
# 3  1.003014e+09                         OTTO                    ROBERT
# 4  1.003018e+09                         TODD                    JOSHUA
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0                 K               FNP                     F                 I
# 1              None              M.D.                     M                 I
# 2                 P              M.D.                     M                 I
# 3                 J              M.D.                     M                 I
# 4                 W              M.D.                     M                 I
#
#             nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# 0       TENNESSEE PRISON FOR WOMEN     3881 STEWARTS LANE           NASHVILLE
# 1              2240 SUTHERLAND AVE              SUITE 103           KNOXVILLE
# 2                 1822 MEMORIAL DR                   None         CLARKSVILLE
# 3  2400 PATTERSON STREET SUITE 100                   None           NASHVILLE
# 4                1819 W CLINCH AVE              SUITE 108           KNOXVILLE
#
#   nppes_provider_zip5 nppes_provider_zip4 nppes_provider_state  \
# 0               37243                0001                   TN
# 1               37919                2333                   TN
# 2               37043                4605                   TN
# 3               37203                2786                   TN
# 4               37916                2435                   TN
#
#   nppes_provider_country specialty_description description_flag  \
# 0                     US    Nurse Practitioner                S
# 1                     US     Pulmonary Disease                S
# 2                     US       Family Practice                S
# 3                     US    Orthopedic Surgery                S
# 4                     US            Cardiology                S
#
#   medicare_prvdr_enroll_status
# 0                            N
# 1                            E
# 2                            E
# 3                            E
# 4                            E

# %%
ovrdose_dths = '''
SELECT * FROM prescriber;
'''
with engine.connect() as connection:
    overdose_deaths = pd.read_sql(text(ovrdose_dths), con = connection)

overdose_deaths.head()

# %%
pop = '''
SELECT * FROM prescriber;
'''

with engine.connect() as connection:
    population = pd.read_sql(text(pop), con = connection)

population.head()
# Out:
#             npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1.003000e+09                    BLAKEMORE                     ROSIE
# 1  1.003012e+09                      CUDZILO                     COREY
# 2  1.003013e+09                  GRABENSTEIN                   WILLIAM
# 3  1.003014e+09                         OTTO                    ROBERT
# 4  1.003018e+09                         TODD                    JOSHUA
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0                 K               FNP                     F                 I
# 1              None              M.D.                     M                 I
# 2                 P              M.D.                     M                 I
# 3                 J              M.D.                     M                 I
# 4                 W              M.D.                     M                 I
#
#             nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# 0       TENNESSEE PRISON FOR WOMEN     3881 STEWARTS LANE           NASHVILLE
# 1              2240 SUTHERLAND AVE              SUITE 103           KNOXVILLE
# 2                 1822 MEMORIAL DR                   None         CLARKSVILLE
# 3  2400 PATTERSON STREET SUITE 100                   None           NASHVILLE
# 4                1819 W CLINCH AVE              SUITE 108           KNOXVILLE
#
#   nppes_provider_zip5 nppes_provider_zip4 nppes_provider_state  \
# 0               37243                0001                   TN
# 1               37919                2333                   TN
# 2               37043                4605                   TN
# 3               37203                2786                   TN
# 4               37916                2435                   TN
#
#   nppes_provider_country specialty_description description_flag  \
# 0                     US    Nurse Practitioner                S
# 1                     US     Pulmonary Disease                S
# 2                     US       Family Practice                S
# 3                     US    Orthopedic Surgery                S
# 4                     US            Cardiology                S
#
#   medicare_prvdr_enroll_status
# 0                            N
# 1                            E
# 2                            E
# 3                            E
# 4                            E

# %%
prescrip = '''
SELECT * FROM prescriber;
'''
with engine.connect() as connection:
    prescription = pd.read_sql(text(prescrip), con = connection)

prescription.head()

# %%
zip = '''
SELECT * FROM prescriber;
'''
with engine.connect() as connection:
    zip_fips = pd.read_sql(text(zip), con = connection)

zip_fips.head()
# Out:
#             npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1.003000e+09                    BLAKEMORE                     ROSIE
# 1  1.003012e+09                      CUDZILO                     COREY
# 2  1.003013e+09                  GRABENSTEIN                   WILLIAM
# 3  1.003014e+09                         OTTO                    ROBERT
# 4  1.003018e+09                         TODD                    JOSHUA
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0                 K               FNP                     F                 I
# 1              None              M.D.                     M                 I
# 2                 P              M.D.                     M                 I
# 3                 J              M.D.                     M                 I
# 4                 W              M.D.                     M                 I
#
#             nppes_provider_street1 nppes_provider_street2 nppes_provider_city  \
# 0       TENNESSEE PRISON FOR WOMEN     3881 STEWARTS LANE           NASHVILLE
# 1              2240 SUTHERLAND AVE              SUITE 103           KNOXVILLE
# 2                 1822 MEMORIAL DR                   None         CLARKSVILLE
# 3  2400 PATTERSON STREET SUITE 100                   None           NASHVILLE
# 4                1819 W CLINCH AVE              SUITE 108           KNOXVILLE
#
#   nppes_provider_zip5 nppes_provider_zip4 nppes_provider_state  \
# 0               37243                0001                   TN
# 1               37919                2333                   TN
# 2               37043                4605                   TN
# 3               37203                2786                   TN
# 4               37916                2435                   TN
#
#   nppes_provider_country specialty_description description_flag  \
# 0                     US    Nurse Practitioner                S
# 1                     US     Pulmonary Disease                S
# 2                     US       Family Practice                S
# 3                     US    Orthopedic Surgery                S
# 4                     US            Cardiology                S
#
#   medicare_prvdr_enroll_status
# 0                            N
# 1                            E
# 2                            E
# 3                            E
# 4                            E

# %%
# Which Tennessee counties had a disproportionately high number of opioid prescriptions?

# %%
# Who are the top opioid prescibers for the state of Tennessee?

# %%
# What did the trend in overdose deaths due to opioids look like in Tennessee from 2015 to 2018?

# %%
# Is there an association between rates of opioid prescriptions and overdose deaths by county?

# %%
# Is there any association between a particular type of opioid and number of overdose deaths?
