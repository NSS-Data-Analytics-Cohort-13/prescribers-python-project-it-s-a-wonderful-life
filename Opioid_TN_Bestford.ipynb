# %%
# !pip install psycopg2

# %%
from sqlalchemy import create_engine, text

# %%
database_name = 'pgadmin'    # Fill this in with your prescribers database name

connection_string = f"postgresql://postgres:postgres@localhost:5432/{database_name}"

# %%
engine = create_engine(connection_string)

# %%
import pandas as pd

# %%
prescriber1 = '''
SELECT * FROM prescriber
'''
with engine.connect() as connection:
    prescriber = pd.read_sql(text(prescriber1), con = connection)

prescriber.head()
# Out:
#             npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1.003000e+09                    BLAKEMORE                     ROSIE
# 1  1.003012e+09                      CUDZILO                     COREY
# 2  1.003013e+09                  GRABENSTEIN                   WILLIAM
# 3  1.003014e+09                         OTTO                    ROBERT
# 4  1.003018e+09                         TODD                    JOSHUA
#
#   nppes_provider_mi nppes_credentials nppes_provider_gender nppes_entity_code  \
# 0                 K               FNP                     F                 I
# 1              None              M.D.                     M                 I
# 2                 P              M.D.                     M                 I
# 3                 J              M.D.                     M                 I
# 4                 W              M.D.                     M                 I
#
# ...

# %%
drug1 = '''
SELECT * FROM drug
'''

# %%
with engine.connect() as connection:
    drug = pd.read_sql(text(drug1), con = connection)

drug.head()
# Out:
#                         drug_name                    generic_name  \
# 0        1ST TIER UNIFINE PENTIPS            PEN NEEDLE, DIABETIC
# 1   1ST TIER UNIFINE PENTIPS PLUS            PEN NEEDLE, DIABETIC
# 2                        ABACAVIR                ABACAVIR SULFATE
# 3             ABACAVIR-LAMIVUDINE     ABACAVIR SULFATE/LAMIVUDINE
# 4  ABACAVIR-LAMIVUDINE-ZIDOVUDINE  ABACAVIR/LAMIVUDINE/ZIDOVUDINE
#
#   opioid_drug_flag long_acting_opioid_drug_flag antibiotic_drug_flag  \
# 0                N                            N                    N
# 1                N                            N                    N
# 2                N                            N                    N
# 3                N                            N                    N
# 4                N                            N                    N
#
#   antipsychotic_drug_flag
# 0                       N
# 1                       N
# 2                       N
# 3                       N
# ...

# %%
cbsa1 = '''
SELECT * FROM cbsa 
'''

with engine.connect() as connection:
    cbsa = pd.read_sql(text(cbsa1), con = connection)

cbsa.head()
# Out:
#   fipscounty   cbsa                          cbsaname
# 0      01001  33860                    Montgomery, AL
# 1      01003  19300         Daphne-Fairhope-Foley, AL
# 2      01007  13820             Birmingham-Hoover, AL
# 3      01009  13820             Birmingham-Hoover, AL
# 4      01015  11500  Anniston-Oxford-Jacksonville, AL

# %%
overdose_death1 = '''
SELECT * FROM cbsa 
'''

with engine.connect() as connection:
    overdose_death = pd.read_sql(text(overdose_death1), con = connection)

overdose_death.head()
# Out:
#   fipscounty   cbsa                          cbsaname
# 0      01001  33860                    Montgomery, AL
# 1      01003  19300         Daphne-Fairhope-Foley, AL
# 2      01007  13820             Birmingham-Hoover, AL
# 3      01009  13820             Birmingham-Hoover, AL
# 4      01015  11500  Anniston-Oxford-Jacksonville, AL

# %%
fips_county1 = '''
SELECT * FROM fips_county 
'''

with engine.connect() as connection:
    fips_county = pd.read_sql(text(fips_county1), con = connection)

fips_county.head()
# Out:
#     county state fipscounty fipsstate
# 0  AUTAUGA    AL      01001        01
# 1  BALDWIN    AL      01003        01
# 2  BARBOUR    AL      01005        01
# 3     BIBB    AL      01007        01
# 4   BLOUNT    AL      01009        01

# %%
population1 = '''
SELECT * FROM population 
'''

with engine.connect() as connection:
    population = pd.read_sql(text(population1), con = connection)

population.head()
# Out:
#   fipscounty  population
# 0      47017     28137.0
# 1      47023     17097.0
# 2      47039     11681.0
# 3      47037    678322.0
# 4      47087     11573.0

# %%
zip_fips1 = '''
SELECT * FROM zip_fips 
'''

with engine.connect() as connection:
    zip_fips = pd.read_sql(text(zip_fips1), con = connection)

zip_fips.head()
# Out:
#      zip fipscounty  res_ratio  bus_ratio  oth_ratio  tot_ratio
# 0  00501      36103   0.000000    1.00000   0.000000   1.000000
# 1  00601      72113   0.160724    0.20098   0.128834   0.162500
# 2  00601      72001   0.839276    0.79902   0.871166   0.837500
# 3  00602      72003   1.000000    0.99880   1.000000   0.999919
# 4  00602      72005   0.000000    0.00120   0.000000   0.000081

# %%
prescription1 = '''
SELECT * FROM prescription 
'''

with engine.connect() as connection:
    prescription = pd.read_sql(text(prescription1), con = connection)

prescription.head()
# Out:
#             npi       drug_name  bene_count  total_claim_count  \
# 0  1.427076e+09  RALOXIFENE HCL         NaN               18.0
# 1  1.003858e+09     GLIMEPIRIDE         NaN               12.0
# 2  1.184627e+09  TAMSULOSIN HCL         NaN               14.0
# 3  1.306111e+09         SPIRIVA         NaN               13.0
# 4  1.285658e+09         SPIRIVA         NaN               13.0
#
#    total_30_day_fill_count  total_day_supply  total_drug_cost  \
# 0                     28.0             840.0          1009.66
# 1                     16.0             480.0           270.86
# 2                     24.0             698.0           353.62
# 3                     13.0             390.0          4783.28
# 4                     13.0             390.0          4855.95
#
#    bene_count_ge65 bene_count_ge65_suppress_flag  total_claim_count_ge65  \
# 0              NaN                             *                    18.0
# ...

# %%
tn_county=fips_county[fips_county['state']=='TN']

# %%
tn_county
# Out:
#           county state fipscounty fipsstate
# 2470    ANDERSON    TN      47001        47
# 2471     BEDFORD    TN      47003        47
# 2472      BENTON    TN      47005        47
# 2473     BLEDSOE    TN      47007        47
# 2474      BLOUNT    TN      47009        47
# ...          ...   ...        ...       ...
# 2561     WEAKLEY    TN      47183        47
# 2562       WHITE    TN      47185        47
# 2563  WILLIAMSON    TN      47187        47
# 2564      WILSON    TN      47189        47
# 2565   STATEWIDE    TN      47990        47
#
# [96 rows x 4 columns]

# %%
opioid=drug[drug['opioid_drug_flag']=='Y']

# %%
opioid
# Out:
#                          drug_name                   generic_name  \
# 10                         ABSTRAL               FENTANYL CITRATE
# 18    ACETAMIN-CAFF-DIHYDROCODEINE  ACETAMINOPHEN/CAFF/DIHYDROCOD
# 19           ACETAMINOPHEN-CODEINE     ACETAMINOPHEN WITH CODEINE
# 33                           ACTIQ               FENTANYL CITRATE
# 212                       ARYMO ER               MORPHINE SULFATE
# ...                            ...                            ...
# 3310                  XODOL 10-300      HYDROCODONE/ACETAMINOPHEN
# 3311                 XODOL 7.5-300      HYDROCODONE/ACETAMINOPHEN
# 3316                    XTAMPZA ER            OXYCODONE MYRISTATE
# 3323                      XYLON 10          HYDROCODONE/IBUPROFEN
# 3381                    ZOHYDRO ER         HYDROCODONE BITARTRATE
#
#      opioid_drug_flag long_acting_opioid_drug_flag antibiotic_drug_flag  \
# 10                  Y                            N                    N
# ...

# %%
merged_tables=pd.merge(drug,prescription, on = ['drug_name'], how='inner')

# %%
merged_tables
# Out:
#        drug_name         generic_name opioid_drug_flag  \
# 0       ABACAVIR     ABACAVIR SULFATE                N
# 1       ABACAVIR     ABACAVIR SULFATE                N
# 2       ABACAVIR     ABACAVIR SULFATE                N
# 3       ABACAVIR     ABACAVIR SULFATE                N
# 4       ABACAVIR     ABACAVIR SULFATE                N
# ...          ...                  ...              ...
# 705010    ZYTIGA  ABIRATERONE ACETATE                N
# 705011    ZYTIGA  ABIRATERONE ACETATE                N
# 705012    ZYTIGA  ABIRATERONE ACETATE                N
# 705013    ZYTIGA  ABIRATERONE ACETATE                N
# 705014    ZYTIGA  ABIRATERONE ACETATE                N
#
#        long_acting_opioid_drug_flag antibiotic_drug_flag  \
# 0                                 N                    N
# 1                                 N                    N
# 2                                 N                    N
# 3                                 N                    N
# ...

# %%
merged_tables=pd.merge(prescription,prescriber, on = ['npi'], how='inner')

# %%
merged_tables
# Out:
#                  npi                  drug_name  bene_count  \
# 0       1.427076e+09             RALOXIFENE HCL         NaN
# 1       1.427076e+09          CIPROFLOXACIN HCL        33.0
# 2       1.427076e+09       ESCITALOPRAM OXALATE         NaN
# 3       1.427076e+09                    AMITIZA         NaN
# 4       1.427076e+09                   ATENOLOL        30.0
# ...              ...                        ...         ...
# 656053  1.912388e+09  HYDROCODONE-ACETAMINOPHEN        17.0
# 656054  1.205876e+09  HYDROCODONE-ACETAMINOPHEN        35.0
# 656055  1.851718e+09     FLUTICASONE PROPIONATE        17.0
# 656056  1.336125e+09         CARBIDOPA-LEVODOPA         NaN
# 656057  1.659640e+09  HYDROCODONE-ACETAMINOPHEN        27.0
#
#         total_claim_count  total_30_day_fill_count  total_day_supply  \
# 0                    18.0                     28.0             840.0
# 1                    40.0                     40.0             328.0
# ...

# %%
merged_tables=pd.merge(prescriber,zip_fips, on = ['nppes_provider_zip5, zip'], how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3024\2149772881.py in ?()
# ----> 1 merged_tables=pd.merge(prescriber,zip_fips, on = ['nppes_provider_zip5, zip'], how='inner')
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
# ...

# %% [markdown]
# Which Tennessee counties had a disproportionately high number of opioid prescriptions?

# %% [markdown]
# Who are the top opioid prescibers for the state of Tennessee?

# %% [markdown]
# What did the trend in overdose deaths due to opioids look like in Tennessee from 2015 to 2018?

# %% [markdown]
# Is there an association between rates of opioid prescriptions and overdose deaths by county?

# %% [markdown]
# Is there any association between a particular type of opioid and number of overdose deaths?
